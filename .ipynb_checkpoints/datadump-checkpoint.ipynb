# %%
import csv
import pandas as pd
import numpy as np
import matplotlib as plt



file = open('rd.txt','r')
reader = csv.reader(file)

data = pd.read_csv(file, skiprows=13, sep='\t')

data[0:]
# Out:
#        X Coordinate      Irradiance_x    Y Coordinate      Irradiance_y
# 0             -17.0      7.690000e-08          -17.00      2.190000e-08
# 1             -16.8      7.730000e-08          -16.70      2.220000e-08
# 2             -16.7      7.720000e-08          -16.40      2.290000e-08
# 3             -16.6      7.700000e-08          -16.20      2.300000e-08
# 4             -16.4      7.770000e-08          -15.90      2.280000e-08
# 5             -16.3      7.900000e-08          -15.70      2.250000e-08
# 6             -16.2      8.030000e-08          -15.40      2.280000e-08
# 7             -16.1      8.130000e-08          -15.10      2.360000e-08
# 8             -15.9      8.180000e-08          -14.90      2.490000e-08
# 9             -15.8      8.180000e-08          -14.60      2.620000e-08
# 10            -15.7      8.150000e-08          -14.30      2.730000e-08
# 11            -15.5      8.110000e-08          -14.10      2.820000e-08
# ...
